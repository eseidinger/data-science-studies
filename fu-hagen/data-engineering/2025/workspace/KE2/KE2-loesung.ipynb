# %% [raw]
# Name:
# Matrikelnummer:

# %% [markdown]
# > Was wir wissen, ist ein Tropfen; was wir nicht wissen, ein Ozean
#
# ___
#
# In dieser Kurseinheit werden wir uns mit dem Datensatz vertraut machen und werden einige Fragen zur Datenqualität diskutieren.
#
# **_Bitte beachten:_**
#
# - In Raw-Zellen erwarten wir Antworten im Freitext-Format. In Code-Zellen soll Code eingefügt werden, bei Bedarf mit Kommentaren. Weitere Formate werden mit Markdown bearbeitet.
# - Fragestellungen sind teilweise bewusst etwas offener formuliert, weil Sie auch im Arbeitsleben nur selten mit ganz spezifischen Anweisungen rechnen können. Es gibt häufig mehrere mögliche Lösungen, dies wird in der Korrektur berücksichtigt.
#
# ___
#
# Ziel ist es, die Zugänglichkeit von Lebensmitteln und Trinkwasser für die Bevölkerung in Deutschland zu analysieren.
#
# In diesem Kurs werden wir die Daten von Mundraub und Refill-Deutschland verwenden, um die Verfügbarkeit von kostenlosem Wasser und Lebensmitteln in Deutschland zu bewerten.
# Refill-Deutschland und Mundraub sind Plattformen, die die Standorte von Früchten, Pflanzen und Zapfstellen in Deutschland erfassen. Die Datensätze stammen von <a href="https://www.govdata.de/">GovData</a>, einem deutschen Datenportal, das einen einheitlichen und zentralen Zugang zu Verwaltungsdaten von Bund, Ländern und Kommunen sowie zu Forschungsdaten bietet. Beide Datensätze beinhalten geographische Punkte, an denen es freien Zugang zu Wasser und Lebensmitteln gibt.
#
# Zur Beantwortung der Fragen werden teilweise zusätzliche Informationen benötigt. Daher **_gibt es unter dem Ordner `media` einen Offline-Zugang zu den angepassten Inhalten_** der beiden Plattformen. Es wird empfohlen, diese Seiten generell zu erkunden.
# In diesem Ordner finden Sie auch Bilder, deren Name mit `GovData` beginnt. Diese Bilder sind Screenshots der Seiten, von denen die Daten stammen.
#
# Es ist auch nützlich, eine gute Dokumentation für zukünftige Aufgaben zu haben, also zögern Sie nicht, sich Notizen zu machen oder Fragen am Ende dieses Protokolls zu stellen :)

# %%
# Imports
import pandas as pd

# %% [markdown]
# Zunächst betrachten wir den Datensatz von Refill-Deutschland, den Sie in Moodle unter dem Namen *refill.csv* finden. Laden Sie diesen Datensatz in einen Pandas-DataFrame mit dem Namen `df_refill` und geben Sie die ersten 5 Zeilen aus.

# %%
# Daten laden
df_refill = pd.read_csv("KE2/refill.csv")
df_refill.head(5)
# Out:
#                        FID                                         geom  \
# 0  MRN_Refill_4326_Point.1  POINT (8.465881798633319 49.48506140126151)
# 1  MRN_Refill_4326_Point.2   POINT (8.68860304760216 49.41426788895124)
# 2  MRN_Refill_4326_Point.3  POINT (8.703600032582694 49.37469998345463)
# 3  MRN_Refill_4326_Point.4  POINT (8.474144008231416 49.48366778413005)
# 4  MRN_Refill_4326_Point.5  POINT (8.376415375795409 49.38466715597765)
#
#                                  id  \
# 0  f6b479c4210c45c1b0282138ebde8f2f
# 1  d24bcae66e96437fa8f998162196524e
# 2  d131c294325d4599ad0a7009ab35e140
# 3  e913384994cf41758097f97743b11b44
# 4  2f7dfcf4261a4ae9a1e4c58d788dc7aa
#
#                                             title  \
# 0                                    Umgekrempelt
# 1                              Annas Unverpacktes
# 2  Refill-Station im Stadtteilverein Boxberg e.V.
# 3                             Wasserturm Mannheim
# 4                                       Weltladen
#
# ...

# %% [markdown]
# # Data Fit
# Bei den folgenden Fragen handelt es sich um eine Einschätzung. Ziel ist es, sich mit dem Thema Datenqualität auseinanderzusetzen und sich mit Fragen der Data Fitness zu beschäftigen.

# %% [markdown]
# ## Fitness-Schnellcheck
# Führen Sie einen kurzen Fitness-Check des Datensatzes durch. Geben Sie hierfür in 1-2 kurzen Sätzen eine erste Einschätzung zur Verwendbarkeit des Datensatzes ab.

# %% [raw]
# Der Datensatz enthält hauptsächlich die geographischen Standorte der Unternehmen, die kostenlose Wasser-Nachfüllstationen anbieten. Da keine Informationen über Lebensmittel enthalten sind, reicht er zur Beantwortung der Forschungsfrage nicht aus und muss ergänzt werden.

# %% [markdown]
# ## Zusatzjoker
# Reichen die zur Verfügung gestellten Informationen aus, um die Frage über die  Erreichbarkeit von Lebensmitteln und Trinkwasser in Deutschland zu beantworten?

# %% [raw]
# Die ursprünglich gestellte Frage kann, wie bereits erwähnt, mit dem vorliegenden Datensatz nur teilweise beantwortet werden.

# %% [markdown]
# ## Einkaufsliste
# Welche Informationen würden Sie zusätzlich verwenden?

# %% [raw]
# Geographische Orte mit kostenlosem Zugang zu Lebensmitteln.

# %% [markdown]
# ## Wiederverwenden, Recyceln und Reduzieren
# Für welche weiteren Fragestellungen/Analysen könnte der Datensatz geeignet sein?

# %% [raw]
# * Analyse zum social engagement in der unterschiedliche Städten.
# * Kulanzanalyse von Restaurants und Cafés in Bezug auf den kostenlosen
#  Ausschank von Wasser.

# %% [markdown]
# ## Datenernte
# Stellen Sie Überlegungen zur Datenerhebung an. Welche Faktoren könnten die Datenqualität beeinträchtigen?

# %% [raw]
# * Fehler bei der manuellen Dateneingabe und Kodierungsfehler. Die Integration verschiedener Datenformate kann zu Fehlern oder Informationsverlusten führen.
# * Schlecht formulierte oder unklare Fragen können zu Verwirrung und damit zu falschen oder irrelevanten Eingaben führen.
# * Die Ergebnisse können nicht repräsentativ sein, wenn die Beteiligung nicht signifikant ist.
# * Fehlende Daten oder unvollständige Daten.
# * Die erhobenen Daten spiegeln möglicherweise nicht die aktuelle Realität wider.
# * Wenn sich die Bedingungen, unter denen die Daten erhoben werden, im Laufe der Zeit ändern.

# %% [markdown]
# Führen Sie die folgende Zelle aus, um die Spalte `description` näher zu betrachten.

# %%
df_refill['description']
# Out:
# 0      Faire Kleidung die nicht nur auf Labels sonder...
# 1      Unverpackte Biolebensmittel nachhaltiges und r...
# 2      Der Stadtteilverein Boxberg e.V. geht mit der ...
# 3                         Öffnungszeiten: immer geöffnet
# 4                                     Fairtrade Produkte
#                              ...
# 176    Öffnungszeiten Mo-Fr 10:00-19:00 Sa 10:00-16:0...
# 177    Öffnungszeiten: Mo-Do 07:30-21:00 Fr;Sa 07:30-...
# 178                    Öffnungszeiten: Mo-Sa 08:30-20:15
# 179                   Öffnungszeiten: Mo-Sa 9:30-20:00
# 180    Caffee-Haus Kette die in der EU keine Steuern ...
# Name: description, Length: 181, dtype: object

# %% [markdown]
# Die Spalte `openinghours` ist eine Spalte, in der die Öffnungszeiten der Refill-Stationen erfasst werden. Es ist jedoch zu beachten, dass in einigen Fällen die Öffnungszeiten in der Spalte `description` erfasst wurden.
#
# ## Die Eindringlinge
# Wie kommen diese Verunreinigungen in den Datensatz? Welche anderen Spalten sind betroffen?

# %% [raw]
# Menschliche Probleme: Die Informationen zu den Datensätzen wurden von einer Vielzahl von Akteuren eingegeben.
# Grob gesagt sind die Spalten 'openinghours' und 'description' betroffen, aber es gibt noch weitere Spalten, die betroffen sind, wie z.B. Elemente aus `addresslocality` oder `streetaddress`  in der Spalte `title`.

# %% [markdown]
# ## Treu bleiben
# Können wir uns nach näherer Betrachtung des Datensatzes noch auf die Daten verlassen?

# %% [raw]
# Da die Informationen von den Interessenten selbst stammen und u.a. als Werbeträger für das Unternehmen dienen, könnte man sagen, dass der Datensatz korrekte, aber falsch formatierte Informationen enthält.

# %% [markdown]
# ## Miss Daten
# Ist dieser Datensatz repräsentativ, warum?

# %% [raw]
# Nein, denn es kann nicht geschlossen werden, dass die Punkte im Datensatz die einzigen Orte in Deutschland sind, an denen kostenlos Wasser nachgefüllt werden kann. Bei der Beurteilung dieser Frage ist jedoch der angegebene Kontext zu berücksichtigen, siehe Buch.

# %% [markdown]
# # Data Integrity
# In diesem Teil werden weitere Fragen anhand des Datensatzes beantwortet. Ziel ist es, Fragen zur Datenqualität und Datenintegrität zu klären.

# %%
# Platz für Tests und Analysen
df_refill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FID              181 non-null    object
#  1   geom             181 non-null    object
#  2   id               181 non-null    object
#  3   title            181 non-null    object
#  4   description      181 non-null    object
#  5   addresslocality  181 non-null    object
#  6   streetaddress    179 non-null    object
#  7   postalcode       178 non-null    object
#  8   email            72 non-null     object
#  9   openinghours     67 non-null     object
#  10  license          181 non-null    object
#  11  telephone        66 non-null     object
# dtypes: object(12)
# memory usage: 17.1+ KB

# %% [markdown]
# ## Refill-Deutschland's size
# Wie viele Zeilen und Spalten hat der Datensatz?

# %% [raw]
# 181 Zeilen und 12 Spalten.

# %% [markdown]
# ## Refill-Deutschland's Merkmale Analyze
# Bestimmen Sie, wenn möglich, die statistischen Merkmale der numerischen Spalten. Tragen Sie die erhaltenen Informationen in die nachstehende Tabelle ein.
#
# *Hinweis:* Wenn Sie weitere Tipps benötigen, verwenden Sie den Schieberegler unten.

# %% [markdown]
# - Unter der Kategorie _**Möglicher Datentyp**_: tragen Sie die primitiven Datentypen (Text, Number, Boolean, Date, usw.) ein.
# - Für die Berechnung der _**Anzahl Fehlende Werte**_ können Sie die folgende Formel verwenden:
# $Fehlende Werte = Gesamtzahl der Werte − Verfügbare Werte$
# - Für die Berechnung der _**Anzahl von wiederholten Werten**_ können Sie die folgende Formel verwenden:
# $Wiederholte Werte = Verfügbare Werte − Anzahl einzigartiger Werte$

# %%
# Platz für Tests und Analysen
df_refill.describe()
# Out:
#                             FID                                         geom  \
# count                       181                                          181
# unique                      181                                          179
# top     MRN_Refill_4326_Point.1  POINT (8.467235978910344 49.48959098173752)
# freq                          1                                            2
#
#                                       id            title  \
# count                                181              181
# unique                               181              173
# top     f6b479c4210c45c1b0282138ebde8f2f  Bloom's Friseur
# freq                                   1                4
#
#                            description addresslocality    streetaddress  \
# count                              181             181              179
# unique                             169              55              173
# ...

# %% [markdown]
# |Name der Spalte|Möglicher Datentyp|Anzahl Fehlende Werte|Anzahl oder Prozentsatz wiederholende Werte|
# |---------------|------------------|---------------------|-------------------------------------------|
# |FID            | Text             |-                    | 0 (0%)                                    |
# |geom           |**GEOPoint**      |-                    | 2 (1.1%)                                  |
# |id             |**Text**          |-                    | 0 (0%)                                    |
# |title          | Text             |-                    |**8 (4.42%)**                              |
# |description    | Text             |**0**                |**12 (6.63%)**                             |
# |addresslocality|**Text**          |**0**                |**126 (69.61%)**                           |
# |streetaddress  | Text             |**2**                |**6 (3.35%)**                              |
# |postalcode     |**Text**          |**3**                |**113 (63.48%)**                           |
# |email          | Text             |**109**              |**2 (2.78%)**                              |
# |openinghours   | Text             | 114                 |**5 (7.46%)**                              |
# |license        | Text             |-                    |**180 (99.45%)**                           |
# |telephone      |**Text**          |**115**              |**1 (1.52%)**                              |

# %% [markdown]
# ## Refill-Deutschland's wADi (weitere Aspekte der Datenintegrität)
# Füllen Sie die folgende Tabelle (wie für **Complete** gezeigt) mit den weiteren Aspekten der Datenintegrität des Refill-Deutschland-Datensatzes aus.

# %% [markdown]
# |Name                              |Trifft zu|Siehe                                                         |
# |----------------------------------|---------|--------------------------------------------------------------|
# |**Of known provenance (Pedigree)**| Ja      |Datenbereitsteller: Metropolregion Rhein-Neckar. Veröffentlichende Stelle: Metropolregion Rhein-Neckar|
# |**Timely**                        | Ja      |Letzte Änderung: **02.07.2024**. Veröffentlichungsdatum 05.04.2022|
# |**Complete**                      | _Nein_  | _`openinghours`, `email`, `telephone`_                       |
# |**High volume**                   | Nein    |181 Zeilen aber mehr als 7.000 Stationen                      |
# |**Multivariate**                  | Nein    |12 Spalten. Nicht ausreichend.                                |
# |**Atomic**                        | Ja      |                                                              |
# |**Consistent**                    | Nein    |`description`                                                 |
# |**Clear**                         | Ja      |                                                              |
# |**Dimensionally structured**      | Ja      |`streetaddress`, `addresslocality`, `postalcode`              |

# %% [markdown]
# **Of known provenance (Pedigree)**:
# Der Datensatz wurde über die Plattform GovData erworben (siehe `GovData_Refill-Stationen.png`). Eine Station kann auf der Website von Refill-Deutschland hinzugefügt werden, indem die Schritte unter "Refill Station werden" → "Refill Station eintragen" befolgt werden, sodass nur Personen, die teilnehmen möchten, die Station auf der Plattform eintragen können. Wir wissen also, vorher der Datensatz kommt.
#
# **Timely**: Der ursprüngliche Datensatz existiert seit dem 05.04.2022 und wurde am 02.07.2024 aktualisiert, also relativ "kürzlich". Es existiert jedoch eine weitere Aktualisierung vom 05.11.2024. Es wird hier jedoch argumentiert, dass die Daten von Mitte Juli immer noch als aktuell angesehen werden können.
#
# **Complete**: Es fehlen Elemente, z. B. in `openinghours`, `email` und `telephone`, siehe Tabelle "2.2  Refill-Deutschland's Merkmale Analyze".
#
# **High volume**: Der Datensatz, mit dem wir arbeiten, umfasst 181 Stationen. Auf der Refill-Website wird allerdings angegeben, dass über 7.000 Standorte registriert sind. Es bleibt jedoch unklar, ob sich diese 7.000 Standorte ausschließlich auf Refill-Stationen beziehen. Beim Registrierungsprozess wird darauf hingewiesen, dass ein 'Tag' wie "refill-station", "refill" oder "leitungswasser" gesetzt werden muss, damit ein Standort als Station gelistet wird. Man könnte hier also für beide Varianten argumentieren, dass es gegeben ist, aber auch, dass das Kriterium nicht erfüllt ist. Hier kommt es somit auf eine gute Begründung an.
#
# **Multivariate**: Es stehen 12 Attribute zur Verfügung, die die Standorte beschreiben, an denen Wasser nachgefüllt werden kann. Viele dieser Attribute beziehen sich jedoch beispielsweise auf den Standort und beinhalten somit ähnliche Informationen. Aus diesem Grund wird hier argumentiert, dass dieses Merkmal nicht erfüllt ist.
#
# **Atomic**: Die Adressen sind zwar teilweise (z.B. durch "city") aggregiert, mit `streetaddress` oder `geom` lässt sich jedoch die genaue Position bestimmen.
#
# **Consistent**: Wie oben erwähnt, enthält die Spalte `description` komplexe und uneinheitliche Informationen, was die Konsistenz beeinträchtigt.
#
# **Clear**: Die Bezeichnungen der Spalten sind größtenteils klar, allerdings ist auf den ersten Blick nicht ersichtlich, was z.B. der Unterschied zwischen `FID` und `id` ist oder was genau sich hinter `geom` verbirgt. Ebenso ist nicht auf den ersten Blick ersichtlich, was welche Lizenz bedeutet.
#
# **Dimensionally structured**: Mit diesem Datensatz wäre es möglich, eine Klassifizierung der `streetaddress` innerhalb der Stadt nach Stadtteilen vorzunehmen. Zudem könnte man die `postalcode` oder die `addresslocality` nach Bundesländern gruppieren.

# %% [markdown]
# # Data Augmentation
# Wie im Abschnitt zur Data Fitness festgestellt wurde, können wir mit dem bestehenden Datensatz nur die Trinkstellen abdecken. Daher ergänzen wir ihn nun mit dem Datensatz der Mundraub-Plattform.
#
# Laden Sie den neuen Datensatz (*mundraub.csv*) in einen Pandas-DataFrame mit dem Namen `df_mundraub` und geben Sie die ersten 5 Zeilen aus.

# %%
# Daten laden
df_mundraub = pd.read_csv("KE2/mundraub.csv")
df_mundraub.head(5)
# Out:
#                          FID                                    geom    nid  \
# 0  MRN_mundraub_4326_Point.1  POINT (8.263338804245 48.993153441091)  28571
# 1  MRN_mundraub_4326_Point.2  POINT (8.248516917229 49.024991206786)  79252
# 2  MRN_mundraub_4326_Point.3  POINT (8.289130926132 49.027318607402)  82859
# 3  MRN_mundraub_4326_Point.4    POINT (8.258906664941 49.0350144276)   5787
# 4  MRN_mundraub_4326_Point.5   POINT (8.283696770668 49.03583525216)  83205
#
#         kind           street      plz              city  \
# 0   Holunder              NaN  76776.0  Neuburg am Rhein
# 1  Hagebutte              NaN  76767.0         Hagenbach
# 2      Apfel   Am Turnerplatz  76744.0    Wörth am Rhein
# 3   Bärlauch              NaN      NaN               NaN
# 4  Haselnuss  Schlesierstraße  76744.0    Wörth am Rhein
#
#                                          description  \
# 0                                                NaN
# 1  Von der Ampel kommend auf der rechten Seite me...
# ...

# %% [markdown]
# ## Mundraub's size
# Wie viele Zeilen und Spalten hat der Datensatz?

# %% [raw]
# 1365 Zeilen und 10 Spalten.

# %% [markdown]
# ## Mundraub's Merkmale Analyze
# Füllen Sie die folgende Tabelle (wie oben) aus, um die Merkmale des Mundraub-Datensatzes zu analysieren.

# %%
# Platz für Tests und Analysen
for col in df_mundraub:
    cValues= df_mundraub[col].dropna()
    if cValues.count()-cValues.nunique() > 0:
        print("\n>>",col, "values:", cValues.count(), "\n",
              "Unique values:", cValues.nunique(), "\n",
              "Duplicated values:", cValues.count() - cValues.nunique(), "\n",
              "Prozent duplicated:",100*(cValues.count() - cValues.nunique())/cValues.count())
    else:
        print("\n>>",col, "is complete and unique")
# Out:
# >> FID is complete and unique
#
# >> geom values: 1365
#  Unique values: 1298
#  Duplicated values: 67
#  Prozent duplicated: 4.908424908424909
#
# >> nid is complete and unique
#
# >> kind values: 1365
#  Unique values: 32
#  Duplicated values: 1333
#  Prozent duplicated: 97.65567765567765
#
# >> street values: 469
#  Unique values: 298
#  Duplicated values: 171
#  Prozent duplicated: 36.46055437100213
#
# >> plz values: 889
#  Unique values: 136
#  Duplicated values: 753
#  Prozent duplicated: 84.70191226096738
#
# >> city values: 892
#  Unique values: 138
#  Duplicated values: 754
#  Prozent duplicated: 84.52914798206278
#
# >> description values: 1342
#  Unique values: 1144
#  Duplicated values: 198
#  Prozent duplicated: 14.754098360655737
#
# >> created_at values: 1365
#  Unique values: 1285
#  Duplicated values: 80
#  Prozent duplicated: 5.86080586080586
#
# >> url is complete and unique

# %% [markdown]
# |Name der Spalte|Möglicher Datentyp|Anzahl Fehlende Werte|Anzahl oder Prozentsatz wiederholende Werte|
# |---------------|-----------------|---------------------|-------------------------------------------|
# |FID            | Text            | -                   | 0 (0%)                                    |
# |geom           |**GEOPoint**     | -                   |**67 (4.91%)**                             |
# |nid            |**Number**       | -                   |**0 (0%)**                                 |
# |kind           |**Text**         | -                   |**1333 (97.66%)**                          |
# |street         |**Text**         |**896**              |**171 (36.46%)**                           |
# |plz            |**Text**         |**476**              |**753 (84.70%)**                           |
# |city           | Text            |**473**              |**754 (84.53%)**                           |
# |description    |**Text**         |**23**               |**198 (14.75%)**                           |
# |created_at     |**Text**         | -                   |**80 (5.86%)**                             |
# |url            | Text            | -                   | 0 (0%)                                    |

# %% [markdown]
# ## Mundraub's wADi (weitere Aspekte der Datenintegrität)
# Füllen Sie die folgende Tabelle (wie für **High Volume** gezeigt) mit den weiteren Aspekten der Datenintegrität des mundraub-Datensatzes aus.

# %% [markdown]
# |Name                              |Trifft zu|Siehe                                                         |
# |----------------------------------|---------|--------------------------------------------------------------|
# |**Of known provenance (Pedigree)**| Ja      |Datenbereitsteller: Metropolregion Rhein-Neckar. Veröffentlichende Stelle: Metropolregion Rhein-Neckar|
# |**Timely**                        | Ja      |Letzte Änderung: 02.07.2024. Veröffentlichungsdatum 05.04.2022|
# |**Complete**                      | Nein    | `street`, `plz`, `city`, `description`                       |
# |**High volume**                   | _Ja_    |_1365 Zeilen. Die Anzahl der Stationen ist ähnlich wie im Blogeintrag._                     |
# |**Multivariate**                  | Nein    |10 Spalten. Nicht ausreichend.                                |
# |**Atomic**                        | Ja      |                                                              |
# |**Consistent**                    | Nein    |`description`, `created_at`                                   |
# |**Clear**                         | Ja      |                                                              |
# |**Dimensionally structured**      | Ja      |`kind`, `city`                                                |

# %% [markdown]
# **Of known provenance (Pedigree)**: Der Datensatz wurde über die Plattform GovData erworben, siehe `GovData_Mundraub.png`. Jeder Fundort kann nach der Erstellung eines Kontos auf der Mundraub-Website hinzugefügt werden, unter dem Bereich 'Aktivitäten' auf der Mundraub-Seite. Wir wissen also auch hier, vorher die Daten kommen.
#
# **Timely**: Der ursprüngliche Datensatz existiert seit dem 05.04.2022 und wurde am 02.07.2024 aktualisiert, also relativ "kürzlich". Es existiert jedoch eine weitere Aktualisierung vom 05.11.2024. Es wird hier jedoch argumentiert, dass die Daten von Mitte Juli immer noch als aktuell angesehen werden können.
#
# **Complete**: Es fehlen Elemente, z.B. in `street`, `plz`, `city`, `description`, siehe Tabelle "3.2  Mundraub's Merkmale Analyze".
#
# **High volume**: Der verwendete Datensatz umfasst 1365 Stationen. Die Existenz von über 1300 Fundstellen wird auf der Website von Mundraub mit einem Blogeintrag hervorgehoben. Um eine neue Fundstelle hinzuzufügen oder eine bestehende als fehlerhaft zu melden und löschen zu lassen, ist die Erstellung eines Kontos erforderlich (siehe 'Aktivitäten' und 'Mundraub-Regeln'). Daher enthält die Datenbank ausschließlich tatsächlich existierende Fundstellen. Es ist möglich, dass GovData nur einen Teil des Datensatzes bereitstellt. Aus diesem Grund lässt sich keine eindeutige Aussage treffen. Wir argumentieren, dass das Kriterium erfüllt ist. Es ist jedoch ebenso zulässig anzugeben, dass es nicht erfüllt ist oder dass eine eindeutige Bestimmung nicht möglich ist. Entscheidend ist hier eine gut begründete Argumentation!
#
# **Multivariate**: Es stehen 10 Attribute zur Verfügung, die die Fundstellen beschreiben, an denen Lebensmittel geerntet werden können. Ähnlich wie beim Refill-Datensatz beziehen sich jedoch auch hier einige Attribute auf den Standort und beinhalten somit ähnliche Informationen. Deshalb wird auch hier argumentiert, dass dieses Merkmal nicht erfüllt ist.
#
# **Atomic**: Die Adressen sind zwar teilweise (z.B. durch "city") aggregiert, mit `street` oder `geom` lässt sich jedoch die genaue Position bestimmen.
#
# **Consistent**: Wie bereits bei der Refill-Aufgabe erwähnt, enthält die Spalte `description` komplexe und uneinheitliche Informationen. Zusätzlich ist die Spalte `created_at` inkonsistent, da sie manchmal am Ende den Stadt, manchmal die Postleitzahl oder auch nichts enthält.
#
# **Clear**: Die Bezeichnungen der Spalten sind größtenteils klar, allerdings ist auf den ersten Blick nicht ersichtlich, was z.B. der Unterschied zwischen `FID` und `nid` ist oder was genau sich hinter `geom` verbirgt.
#
# **Dimensionally structured**: Hier ist es möglich, eine Klassifizierung nach `kind` oder `city` (wie oben) zu verwenden.

# %% [markdown]
# # Improving Data Quality
# In diesem kurzen Abschnitt geht es auch um eine Einschätzung. Ziel ist es, Sie mit den vorbereitenden Schritten zur Verbesserung der Datensätze vertraut zu machen.
#
# ## TODO-List
# Welche Vorverarbeitungsschritte sind für die Datensätze notwendig?

# %% [raw]
# * Format verifizieren und anpassen
# * Fehlende Werte bereinigen
# * Name der Spalten verbessern
# * Datentyp der Spalten korrigieren

# %% [markdown]
# # Notizen

# %% [raw]
# Persönliche Notizen ;)
