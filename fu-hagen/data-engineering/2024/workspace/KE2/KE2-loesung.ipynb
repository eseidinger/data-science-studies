# %% [raw]
# Name:
# Matrikelnummer:

# %% [markdown]
# ___

# %%
# Imports
import pandas as pd

# %% [markdown]
# ___
# **_Bitte beachten:_**
#
# - In Code-Zellen soll (bei Bedarf kommentierter) Code eingefügt werden. In Raw-Zellen erwarten wir Antworten im Freitext-Format.
# - Fragestellungen sind teilweise bewusst etwas offener formuliert, weil Sie auch im Arbeitsleben nur selten mit ganz spezifischen Anweisungen rechnen können. Es gibt häufig mehrere mögliche Lösungen, dies wird in der Korrektur  berücksichtigt.
#
# ___

# %% [markdown]
# # (I can't get no) satisfaction
# Wir werden in diesem Kurs mit einem Datensatz arbeiten, der verschiedene Informationen über Angestellte einer fiktiven Firma namens *Fiktiva* enthält. Mithilfe des Datensatzes soll die Fragestellung beantwortet werden, ob ein\*e Angestellte\*r in der Firma zufrieden ist (`satisfied = 1`) oder nicht (`satisfied = 0`). In dieser Kurseinheit werden wir uns mit den Daten vertraut machen und mit einigen Fragen zur Datenqualität auseinandersetzen. Wir gehen für die weiteren Analysen davon aus, dass diese Analyse, die Sie nun durchführen, Anfang März 2021 stattfindet (und somit kurz nach der Erhebung der Daten).
#
# Manchmal werden zur Beantwortung von Fragen weitere Informationen benötigt. Sie können hierfür auch externe Quellen verwenden und bspw. die Datei `metadata.txt` zu Rate ziehen, aber auch alle Informationen aus dem Fiktiva-Newsletter.

# %% [markdown]
# ## Daten laden
# Den Datensatz (*employees_satisfaction.csv*) finden Sie im Moodle. Laden Sie ihn in ein Pandas-Dataframe, so dass die erste Spalte als Index (Row Label) verwendet wird. Geben Sie die ersten 10 Zeilen aus.

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Nur korrekt, wenn `index_col=0` angegeben wurde*

# %%
# Ihre Lösung
df = pd.read_csv("data/employees_satisfaction.csv", index_col=0)
# Durch die Verwendung von index_col=0 verhindern wir eine extra Spalte am Anfang
df.head(10)
# Out:
#      emp_id  age        Dept education    recruitment_type  job_level  rating  \
# 0    HR8270   28          HR        PG            Referral          5     2.0
# 1  TECH1860   50  Technology        PG  Recruitment Agency          3     5.0
# 2  TECH6390   43  Technology        UG            Referral          4     1.0
# 3   SAL6191   44       Sales        PG           On-Campus          2     3.0
# 4    HR6734   33          HR        UG  Recruitment Agency          2     1.0
# 5   PUR7265   40  Purchasing        UG             Walk-in          3     3.0
# 6   PUR1466   26  Purchasing        UG            Referral          5     5.0
# 7  TECH5426   25  Technology        UG  Recruitment Agency          1     1.0
# 8    HR6578   35          HR        PG            Referral          3     4.0
# 9  TECH9322   45  Technology        PG            Referral          3     3.0
#
#    awards  certifications  salary  gender  entry_date  last_raise  satisfied
# ...

# %% [markdown]
# ## Erste Datenanalyse

# %% [markdown]
# Machen Sie sich mit den Daten vertraut:
# - Wie viele Zeilen hat der Datensatz?
# - Wie viele Spalten hat der Datensatz?
# - Welche Spalten beinhaltet der Datensatz?
# - Welchen Datentyp haben die einzelnen Spalten?
# - Ermitteln Sie statistische Kennzeichen der numerischen Spalten.
# - Gibt es fehlende Werte in den Daten und wenn ja, bei welchen Spalten?

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Es sind viele unterschiedliche Code-Lösungen möglich, die Hauptsache ist, dass am Ende die Ausgabe des Codes die angegebene Fragestellung beantwortet.*

# %%
# Ihre Lösung (nutzen Sie dafür untenstehende Zellen)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   emp_id            500 non-null    object
#  1   age               500 non-null    int64
#  2   Dept              500 non-null    object
#  3   education         500 non-null    object
#  4   recruitment_type  500 non-null    object
#  5   job_level         500 non-null    int64
#  6   rating            471 non-null    float64
#  7   awards            500 non-null    int64
#  8   certifications    500 non-null    int64
#  9   salary            500 non-null    int64
#  10  gender            497 non-null    object
#  11  entry_date        500 non-null    object
#  12  last_raise        26 non-null     float64
#  13  satisfied         500 non-null    int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 58.6+ KB

# %%
# Wie viele Zeilen hat der Datensatz? 
len(df)
# Out:
# 500

# %%
# Wie viele Spalten hat der Datensatz?
len(df.columns)
# Out:
# 14

# %%
# Welche Spalten beinhaltet der Datensatz?
df.columns
# Out:
# Index(['emp_id', 'age', 'Dept', 'education', 'recruitment_type', 'job_level',
#        'rating', 'awards', 'certifications', 'salary', 'gender', 'entry_date',
#        'last_raise', 'satisfied'],
#       dtype='object')

# %%
# Welchen Datentyp haben die einzelnen Spalten?
df.dtypes
# Out:
# emp_id               object
# age                   int64
# Dept                 object
# education            object
# recruitment_type     object
# job_level             int64
# rating              float64
# awards                int64
# certifications        int64
# salary                int64
# gender               object
# entry_date           object
# last_raise          float64
# satisfied             int64
# dtype: object

# %%
# Ermitteln Sie statistische Kennzeichen der numerischen Spalten.
df.describe()
# Out:
#               age   job_level      rating      awards  certifications  \
# count  500.000000  500.000000  471.000000  500.000000      500.000000
# mean    39.694000    3.032000    3.093418    4.570000        0.514000
# std      8.477033    1.423738    1.423129    2.989812        0.628167
# min     22.000000    1.000000    1.000000    0.000000        0.000000
# 25%     34.000000    2.000000    2.000000    2.000000        0.000000
# 50%     39.000000    3.000000    3.000000    5.000000        0.000000
# 75%     47.000000    4.000000    4.000000    7.000000        1.000000
# max     56.000000    5.000000    5.000000   25.000000        9.000000
#
#              salary  last_raise   satisfied
# count    500.000000   26.000000  500.000000
# mean   50416.056000    0.049231    0.714000
# std    23671.392661    0.029519    0.452342
# min    24076.000000    0.010000    0.000000
# 25%    29805.000000    0.020000    0.000000
# 50%    42419.000000    0.050000    1.000000
# ...

# %%
# Gibt es fehlende Werte in den Daten und wenn ja, bei welchen Spalten?
df.isna().sum()
# Out:
# emp_id                0
# age                   0
# Dept                  0
# education             0
# recruitment_type      0
# job_level             0
# rating               29
# awards                0
# certifications        0
# salary                0
# gender                3
# entry_date            0
# last_raise          474
# satisfied             0
# dtype: int64

# %%
# Alternativen
df.info()
df.count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   emp_id            500 non-null    object
#  1   age               500 non-null    int64
#  2   Dept              500 non-null    object
#  3   education         500 non-null    object
#  4   recruitment_type  500 non-null    object
#  5   job_level         500 non-null    int64
#  6   rating            471 non-null    float64
#  7   awards            500 non-null    int64
#  8   certifications    500 non-null    int64
#  9   salary            500 non-null    int64
#  10  gender            497 non-null    object
#  11  entry_date        500 non-null    object
#  12  last_raise        26 non-null     float64
#  13  satisfied         500 non-null    int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 58.6+ KB
# emp_id              500
# age                 500
# ...

# %% [markdown]
# ## Datenqualität
#
# <div class="alert alert-block alert-warning">
#
# **Hinweis**: Bei den folgenden Fragen geht es um Ihre Einschätzung. Ziel ist es, sich mit dem Thema Datenqualität auseinanderzusetzen und sich mit Fragestellungen in Bezug auf Data Fitness, etc. zu beschäftigen.
#
# </div>

# %% [markdown]
# Was denken Sie über den Datensatz? Ist dieser geeignet, um die Fragestellung über die Zufriedenheit der Angestellten zu beantworten? Reichen die angegebenen Informationen zur Beantwortung der Fragestellung aus? Wenn nicht, welche Informationen würden Sie noch verwenden? Begründen Sie Ihre Antworten.
#
# Hinweis: Bei der Beurteilung geht es um die Daten selbst, nicht um deren Erhebung. Dazu folgt noch eine Fragestellung.

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Wichtig ist hier, dass angegeben wurde, dass die Informationen teilweise hilfreich sind, es sollte aber mindestens eine Einschränkung genannt werden (s.u.). Alle Aussagen müssen immer entsprechend begründet sein!*

# %% [raw]
# Ihre Einschätzung:
# Die Informationen könnten teilweise hilfreich für die Beantwortung der Fragestellung sein, so könnte man z.B. analysieren, ob die Zufriedenheit vom Gehalt abhängig ist. Trotzdem ist die Zufriedenheit ein wesentlich komplexeres Thema und kann vermutlich nicht allein durch die hier angegebenen Informationen beantwortet werden.
# Zudem kann sich Zufriedenheit aus vielen unterschiedlichen Aspekten zusammensetzen, die Kategorien "zufrieden" und "nicht zufrieden" allein, können dieses komplexe Thema evtl. nicht abdecken. Auch konnten in der Umfrage keine Gründe für die (Un-)Zufriedenheit angegeben werden.

# %% [markdown]
# Für welche weiteren Fragestellungen/Analysen könnte der Datensatz geeignet sein? Zählen Sie mindestens drei sinnvolle Aspekte auf.

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Hier sollten mindestens drei sinnvolle Analyse aufgezählt werden.*

# %% [raw]
# Ihre Einschätzung:
# - Analysen zum Alter der Angestellten: Wie alt sind die Angestellten im Schnitt, wie verteilt sich das auf die Abteilungen, welche Auswirkungen hat das Alter auf die Zufriedenheit, ...?
# - Hat sich das Recruiting über die Jahre geändert?
# - Geschlechterverteilung/Ausbildungslevel in den Abteilungen
# - Gender Pay Gap: Für eine detaillierte Analyse sind hier sicher mehr Informationen benötigt, als im Datensatz vorhanden, jedoch können wir hier erste Analysen vornehmen (da wir neben dem Geschlecht ja auch Informationen zu Job Level, Rating, Certifications etc. haben).
# - Weitere Analysen zum Gehalt: Steht das Gehalt bzgl. Ausbildung und Job Level in einem akzeptablem Verhältnis?
# - Weitere siehe KE4

# %% [markdown]
# Stellen Sie Überlegungen zur Datenerhebung an. Welche Faktoren könnten die Datenqualität beeinträchtigen?
# Nennen Sie mindestens zwei Einschränkungen und begründen Sie Ihre Antworten.

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Es sollten mindestens zwei (begründete) Einschränkungen (s.u) genannt werden.*

# %% [raw]
# Ihre Einschätzung:
# - Angestellte mussten ihre eindeutige ID angeben, somit ist die Umfrage nicht anonym. Dies könnte natürlich Einfluss auf die Beantwortung der Frage nach der Zufriedenheit haben.
# - Die Aussage könnte nur eine Momentaufnahme sein.
# - Es macht einen Unterschied, von wem und für wen die Daten erhoben wurden. Von dem/der Vorgesetzten, um über Kündigungen zu entscheiden? Um Kündigungen vorzubeugen? Von einer unabhängigen Insatz, um sich ein allgemeines Bild über die Angestellten-Zufriedenheit zu machen? Je nachdem, könnten Angestellte in ihrer Antwort beeinflusst werden.

# %% [markdown]
# Beurteilen Sie den Datensatz bzgl. der Aspekte zur Datenqualität, die Sie im Kurstext in Kapitel 3 unter "Assessing Data Integrity" kennengelernt haben. Begründen Sie Ihre Antworten.

# %%
# In dieser Zelle haben Sie Platz für Analysen bzgl. der Datenqualität
# Bewertet werden aber nur Ihre Antworten in der untenstehenden Raw-Zelle, gekennzeichnet mit "Ihre Einschätzung"!

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Alle untenstehenden Aspekte sollten genannt und beurteilt worden sein!*

# %% [raw]
# Ihre Einschätzung:
#
# Neccesary but not sufficient:
# - Of known provenance/of known pedigree: Wir wissen, wie die Umfrage erhoben wurde und mit Daten aus dem System verknüpft wurde. Allerdings haben wir keine weiteren Informationen übr diesen Prozess und wie vetrauenswürdig die Daten sind. Wir wissen (wie bei der Frage zur Datenerhebung beschrieben) nicht, von wem und für wen die Daten erhoben wurden: Von dem/der Vorgesetzten, um über Kündigungen zu entscheiden? Um Kündigungen vorzubeugen? Von einer unabhängigen Insatz, um sich ein allgemeines Bild über die Angestellten-Zufriedenheit zu machen? Je nachdem, könnten Angestellte in ihrer Antwort beeinflusst werden.
# - Well-annotated: Die Datei metadata.txt beinhaltet Informationen zu den Daten.
#
# Important:
# - Timely: Im Newsletter ist zu lesen, dass die Firma im Jahr 2004 gegründet wurde und die Umfrage im Februar 2021 erhoben wurde. Da in dem Datensatz Daten von 2004-2020 vorliegen und wir davon ausgehen, dass diese Analyse Anfang März 2021 durchgeführt wird, ist dieses Qualitätskriterium gegeben.
# - Complete: Teilweise fehlende Werte (werden in KE3 behandelt).
# - High volume: Im Newsletter ist zu lesen, dass im Dezember 2020 der 500. Mitarbeiter angestellt wurde. Insgesamt befinden sich 500. Zeilen in dem Datensatz, der letzte vom Dezember 2020. Die Informationen zu diesem Mitarbeiter stimmen mit denen, die im Newsletter angegeben wurden, überein. Wir können also davon ausgehen, dass dieses Qualitätskriterium gegeben ist.
# - Multivariate: Insgesamt stehen uns in diesem Datensazt 14 Features zur Verfügung, bzw. 13 zur Vorhersage der Zufriedenheit.
# - Atomic: Größtenteils gegegeben (keine Aggregationen), aber 0 und 1 keine detaillierte Beschreibung für Zufriedenheit.
#
# Achievable:
# - Consistent: Teilweise nicht gegegeben (siehe Spalte "gender"), wird in KE3 behandelt.
# - Clear: Teilweise nicht gegeben (siehe UG/PG in Spalte education), wird in KE3 behandelt.
# - Dimensionally structured: Wenn Daten "dimensionally structured" sind, dann enthalten sie Features, anhand derer ein Gruppieren möglich ist. Wie im Buch beschrieben bieten solche Features einen schnellen Einstieg z.B. für Data Augmentation, aber auch für die Datenanalyse. In den Daten ist das Department gruppierbar nach den jeweiligen Abteilungsnamen und könnte so mit weiteren Eigenschaften (z.B. Standort der Abteilung o.ä.) angereichert werden. Weitere Kandidaten zum Gruppieren: Department, Gender, Education, Certifications, Job-Level und Recruitment Type
#
# Allgemeine Anmerkungen für Studierende:
# Grundsätzlich ist das Thema Datenqualität an sich nicht abgehandelt durch "Daten haben gute Qualität"/"Daten haben schlechte Qualität". Es lassen sich für die einzelnen Aspekte sicher auch Argumente dafür und dagegen finden. Aus diesem Grund möchten wir betonen, dass die Antworten gut begründet sein sollen. Unser Lehrziel ist es hier, dass sich der unterschiedlichen Aspekte von Datenqualität bewusst gemacht wird, so dass wenn im Job oder auch woanders mit Daten gearbeitet wird, zuerst überlegt wird: Welche Aspekte von Datenqualiät habe ich kennengelernt? Inwiefern erfüllen meine Daten diese und wo vielleicht nicht? Welche Auswirkungen hat das auf mein weiteres Vorgehen? Kann ich die Daten so verwenden? Muss ich weitere Informationen einholen? ...

# %% [markdown]
# Stellen Sie sich vor, dieser Datensatz soll dazu verwendet werden, um die Zufriedenheit von Angestellten vorherzusagen und daraus wiederum Rückschlüsse auf das Kündigungswahrscheinlichkeiten zu schließen. Für wie zuverlässig würden Sie entsprechende Wahrscheinlichkeiten halten? Begründen Sie Ihre Antwort.

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Für eine korrekte Antwort sollte zu dem Schluss gekommen werden, dass diese Wahrscheinlichkeiten vermutlich nicht sehr zuverlässig wären. Wichtig ist aber auch hier eine gute Begründung!*

# %% [raw]
# Ihre Einschätzung:
# - Wie bereits erwähnt, kann sich Zufriedenheit aus vielen unterschiedlichen Aspekten zusammensetzen, die Kategorien "zufrieden" und "nicht zufrieden" allein, können dieses komplexe Thema evtl. nicht abdecken.
# - Wie in der Antwort auf die vorherige Frage beschrieben, könnte die Angabe zur Zufriedenheit zum einen lediglich eine Momentaufnahme sein und zum anderen aufgrund unterschiedlicher Faktoren (nicht-anonymisiert) evtl. nicht ehrlich beantwortet worden sein.
# - Die Zufriedenheit alleine reicht vermutlich nicht aus, um Rückschlüsse auf Kündigungswahrscheinlichekiten zu schließen. Bei unzufriedenen Angestellten wäre die Wahrscheinlichkeit zwar vermutlich höher, dass sie kündigen, aber auch zufriedene Angestellte können aus unterschiedlichen Gründen kündigen, bspw. weil sie sich thematisch verändern wollen oder weil sich ihre Lebensbedingungen ändern oder der Standort nicht mehr für sie passt.
# -> Genannte Wahrscheinlichkeiten zum Kündigungsverhalten wären vermutlich nicht sehr zuverlässig.

# %% [markdown]
# Nehmen Sie an, mithilfe des Datensatzes wäre ein zuverlässiges Modell mit guten Vorhersagewahrscheinlichkeiten trainiert worden, um die Zufriedenheit der Angestellten zu bestimmen. Nun möchte eine andere Firma aus der gleichen Branche dasselbe Modell für ihre Angestellten nutzen. Denken Sie, das Modell würde auch für die andere Firma zuverlässige Vorhersagen treffen? Begründen Sie Ihre Antwort.

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Für eine korrekte Antwort sollte zu dem Schluss gekommen werden, dass ein solches Modell nicht zwangsläufig auch für eine andere Firma geeignet ist. Wichtig ist aber auch hier eine gute Begründung!*

# %% [raw]
# Ihre Einschätzung:
# Nur weil das Modell für eine Firma gut funktioniert, bedeutet das nicht, dass es auch in einer anderen Firma zuverlässige Ergebnisse liefert, auch wenn sich dieses in der gleichen Branche befindet. Es ist ja nicht klar, ob das gleiche System für Job Level, Rating etc. verwendet wird. Außerdem ist die Zufriedenheit wie beschrieben ein sehr komplexes Thema, das von vielen unterschiedlichen Faktoren abhängt, die bei zwei unterschiedlichen Firmen, auch wenn sie sich in der gleichen Branche befinden, komplett unterschiedlich sein können.

# %% [markdown]
# Überlegen Sie, welche Vorverarbeitungsschritte für den Datensatz notwendig wären. Nennen Sie mindestens drei sinnvolle Vorverarbeitungsschritte.

# %% [markdown]
# ***Hinweis zur Korrektur:*** *Es sollten mindestens drei sinnvolle Vorverarbeitungsschritte genannt werden.*

# %% [raw]
# Ihre Einschätzung:
# Mögliche Vorverarbeitungsschritte:
# - Ersetzen fehlender Werte von gender und last_raise
# - Vereinheitlichen der Spalte gender
# - Tranformieren des Gehalts von Dollar in Euro
# - Weitere Schritte siehe Aufgaben KE3
