# %%
from sklearn.datasets import make_classification

X, y = make_classification()

X
# Out:
# array([[ 0.01031712,  1.16409731,  0.88613435, ...,  0.10672557,
#          2.2795006 , -0.18676919],
#        [ 1.45639865, -0.21026788, -0.43814365, ...,  0.18320028,
#          1.67185932, -0.94960924],
#        [-0.00722466, -0.09503627,  1.77760321, ..., -0.45632715,
#         -2.27997379, -0.90351739],
#        ...,
#        [-0.76631896, -0.18044341,  1.04524899, ...,  0.47812872,
#          0.39846815, -1.0064535 ],
#        [-1.35452193,  1.05731701,  2.3472919 , ...,  1.0244269 ,
#         -0.02463332,  0.37722327],
#        [-0.28691061,  0.1610694 , -0.69886375, ..., -0.76852378,
#          2.00406121,  0.44987953]], shape=(100, 20))

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier().fit(X, y)

tree.plot_tree(clf,proportion=True)
# Out:
# [Text(0.5, 0.9375, 'x[3] <= -0.141\ngini = 0.5\nsamples = 100.0%\nvalue = [0.5, 0.5]'),
#  Text(0.25, 0.8125, 'x[16] <= -2.096\ngini = 0.241\nsamples = 50.0%\nvalue = [0.86, 0.14]'),
#  Text(0.375, 0.875, 'True  '),
#  Text(0.125, 0.6875, 'x[19] <= 0.56\ngini = 0.32\nsamples = 5.0%\nvalue = [0.2, 0.8]'),
#  Text(0.0625, 0.5625, 'gini = 0.0\nsamples = 4.0%\nvalue = [0.0, 1.0]'),
#  Text(0.1875, 0.5625, 'gini = 0.0\nsamples = 1.0%\nvalue = [1.0, 0.0]'),
#  Text(0.375, 0.6875, 'x[11] <= -2.129\ngini = 0.124\nsamples = 45.0%\nvalue = [0.933, 0.067]'),
#  Text(0.3125, 0.5625, 'gini = 0.0\nsamples = 1.0%\nvalue = [0.0, 1.0]'),
#  Text(0.4375, 0.5625, 'x[4] <= -1.245\ngini = 0.087\nsamples = 44.0%\nvalue = [0.955, 0.045]'),
#  Text(0.375, 0.4375, 'x[18] <= -0.113\ngini = 0.48\nsamples = 5.0%\nvalue = [0.6, 0.4]'),
#  Text(0.3125, 0.3125, 'gini = 0.0\nsamples = 2.0%\nvalue = [0.0, 1.0]'),
#  Text(0.4375, 0.3125, 'gini = 0.0\nsamples = 3.0%\nvalue = [1.0, 0.0]'),
#  Text(0.5, 0.4375, 'gini = 0.0\nsamples = 39.0%\nvalue = [1.0, 0.0]'),
#  Text(0.75, 0.8125, 'x[19] <= 1.734\ngini = 0.241\nsamples = 50.0%\nvalue = [0.14, 0.86]'),
#  Text(0.625, 0.875, '  False'),
#  Text(0.625, 0.6875, 'x[1] <= -2.681\ngini = 0.19\nsamples = 47.0%\nvalue = [0.106, 0.894]'),
#  Text(0.5625, 0.5625, 'gini = 0.0\nsamples = 1.0%\nvalue = [1.0, 0.0]'),
#  Text(0.6875, 0.5625, 'x[2] <= 2.564\ngini = 0.159\nsamples = 46.0%\nvalue = [0.087, 0.913]'),
#  Text(0.625, 0.4375, 'x[0] <= -1.855\ngini = 0.124\nsamples = 45.0%\nvalue = [0.067, 0.933]'),
#  Text(0.5625, 0.3125, 'gini = 0.0\nsamples = 1.0%\nvalue = [1.0, 0.0]'),
#  Text(0.6875, 0.3125, 'x[5] <= 1.296\ngini = 0.087\nsamples = 44.0%\nvalue = [0.045, 0.955]'),
#  Text(0.625, 0.1875, 'gini = 0.0\nsamples = 40.0%\nvalue = [0.0, 1.0]'),
#  Text(0.75, 0.1875, 'x[0] <= -0.104\ngini = 0.5\nsamples = 4.0%\nvalue = [0.5, 0.5]'),
#  Text(0.6875, 0.0625, 'gini = 0.0\nsamples = 2.0%\nvalue = [1.0, 0.0]'),
#  Text(0.8125, 0.0625, 'gini = 0.0\nsamples = 2.0%\nvalue = [0.0, 1.0]'),
#  Text(0.75, 0.4375, 'gini = 0.0\nsamples = 1.0%\nvalue = [1.0, 0.0]'),
#  Text(0.875, 0.6875, 'x[10] <= -0.026\ngini = 0.444\nsamples = 3.0%\nvalue = [0.667, 0.333]'),
#  Text(0.8125, 0.5625, 'gini = 0.0\nsamples = 1.0%\nvalue = [0.0, 1.0]'),
#  Text(0.9375, 0.5625, 'gini = 0.0\nsamples = 2.0%\nvalue = [1.0, 0.0]')]

# %%
import sklearn.metrics as metrics

metrics.accuracy_score(y,clf.predict(X))
# Out:
# 1.0

# %%
import pandas as pd

df = pd.read_csv("../datasets/dataset_tennis.csv")
df
# Out:
#      outlook temperature humidity    wind tennis
# 0      sunny         hot     high    weak     no
# 1      sunny         hot     high  strong     no
# 2   overcast         hot     high    weak    yes
# 3       rain        mild     high    weak    yes
# 4       rain        cool   normal    weak    yes
# 5       rain        cool   normal  strong     no
# 6   overcast        cool   normal  strong    yes
# 7      sunny        mild     high    weak     no
# 8      sunny        cool   normal    weak    yes
# 9       rain        mild   normal    weak    yes
# 10     sunny        mild   normal  strong    yes
# 11  overcast        mild     high  strong    yes
# 12  overcast         hot   normal    weak    yes
# 13      rain        mild     high  strong     no

# %%
from sklearn.preprocessing import LabelEncoder

X = df.iloc[:, 0:-1].values
y = df.iloc[:, 4].values
le = LabelEncoder()
X[:, 0] = le.fit_transform(X[:, 0])
X[:, 1] = le.fit_transform(X[:, 1])
X[:, 2] = le.fit_transform(X[:, 2])
X[:, 3] = le.fit_transform(X[:, 3])
clf = tree.DecisionTreeClassifier().fit(X, y)

# %%
from sklearn import preprocessing

X_enc = preprocessing.OrdinalEncoder().fit_transform(X)
X_enc
# Out:
# array([[2., 1., 0., 1.],
#        [2., 1., 0., 0.],
#        [0., 1., 0., 1.],
#        [1., 2., 0., 1.],
#        [1., 0., 1., 1.],
#        [1., 0., 1., 0.],
#        [0., 0., 1., 0.],
#        [2., 2., 0., 1.],
#        [2., 0., 1., 1.],
#        [1., 2., 1., 1.],
#        [2., 2., 1., 0.],
#        [0., 2., 0., 0.],
#        [0., 1., 1., 1.],
#        [1., 2., 0., 0.]])

# %%
clf = tree.DecisionTreeClassifier().fit(X_enc, y)

tree.plot_tree(clf,proportion=True)
# Out:
# [Text(0.4444444444444444, 0.9, 'x[0] <= 0.5\ngini = 0.459\nsamples = 100.0%\nvalue = [0.357, 0.643]'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.0\nsamples = 28.6%\nvalue = [0.0, 1.0]'),
#  Text(0.38888888888888884, 0.8, 'True  '),
#  Text(0.5555555555555556, 0.7, 'x[2] <= 0.5\ngini = 0.5\nsamples = 71.4%\nvalue = [0.5, 0.5]'),
#  Text(0.5, 0.8, '  False'),
#  Text(0.3333333333333333, 0.5, 'x[0] <= 1.5\ngini = 0.32\nsamples = 35.7%\nvalue = [0.8, 0.2]'),
#  Text(0.2222222222222222, 0.3, 'x[3] <= 0.5\ngini = 0.5\nsamples = 14.3%\nvalue = [0.5, 0.5]'),
#  Text(0.1111111111111111, 0.1, 'gini = 0.0\nsamples = 7.1%\nvalue = [1.0, 0.0]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 7.1%\nvalue = [0.0, 1.0]'),
#  Text(0.4444444444444444, 0.3, 'gini = 0.0\nsamples = 21.4%\nvalue = [1.0, 0.0]'),
#  Text(0.7777777777777778, 0.5, 'x[3] <= 0.5\ngini = 0.32\nsamples = 35.7%\nvalue = [0.2, 0.8]'),
#  Text(0.6666666666666666, 0.3, 'x[1] <= 1.0\ngini = 0.5\nsamples = 14.3%\nvalue = [0.5, 0.5]'),
#  Text(0.5555555555555556, 0.1, 'gini = 0.0\nsamples = 7.1%\nvalue = [1.0, 0.0]'),
#  Text(0.7777777777777778, 0.1, 'gini = 0.0\nsamples = 7.1%\nvalue = [0.0, 1.0]'),
#  Text(0.8888888888888888, 0.3, 'gini = 0.0\nsamples = 21.4%\nvalue = [0.0, 1.0]')]
